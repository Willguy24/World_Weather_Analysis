# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 786

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malabo
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | shitkino
# Processing Record 7 of Set 1 | ponta delgada
# Processing Record 8 of Set 1 | rawson
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | faya
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | vestmannaeyjar
# Processing Record 15 of Set 1 | port hedland
# Processing Record 16 of Set 1 | souillac
# Processing Record 17 of Set 1 | nanortalik
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | charters towers
# Processing Record 23 of Set 1 | tautira
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | jiwani
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | peterhead
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | ballina
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | huaihua
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | mancio lima
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | taltal
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | lavrentiya
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | govindgarh
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | bourg-en-bresse
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | illapel
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | aksu
# Processing Record 10 of Set 2 | mendoza
# Processing Record 11 of Set 2 | seoul
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | ozernovskiy
# Processing Record 14 of Set 2 | beringovskiy
# Processing Record 15 of Set 2 | popova
# Processing Record 16 of Set 2 | lata
# Processing Record 17 of Set 2 | haines junction
# Processing Record 18 of Set 2 | saint-pierre
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | maldonado
# Processing Record 21 of Set 2 | kourou
# Processing Record 22 of Set 2 | ostersund
# Processing Record 23 of Set 2 | staryy nadym
# Processing Record 24 of Set 2 | migori
# Processing Record 25 of Set 2 | caravelas
# Processing Record 26 of Set 2 | talara
# Processing Record 27 of Set 2 | puerto leguizamo
# Processing Record 28 of Set 2 | flinders
# Processing Record 29 of Set 2 | ondjiva
# Processing Record 30 of Set 2 | havre-saint-pierre
# Processing Record 31 of Set 2 | salina cruz
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | shyryayeve
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | presidente olegario
# Processing Record 38 of Set 2 | constitucion
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | castelo do piaui
# Processing Record 41 of Set 2 | kaputa
# Processing Record 42 of Set 2 | kirakira
# Processing Record 43 of Set 2 | lorengau
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | adrar
# Processing Record 46 of Set 2 | berlevag
# Processing Record 47 of Set 2 | amapa
# Processing Record 48 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 2 | karimpur
# Processing Record 50 of Set 2 | warrington
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | bereda
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | buritis
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | poya
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | anloga
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | worland
# Processing Record 16 of Set 3 | kaeo
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | avera
# Processing Record 20 of Set 3 | iquique
# Processing Record 21 of Set 3 | pingzhuang
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | kahului
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | la ronge
# Processing Record 27 of Set 3 | sosnovo-ozerskoye
# Processing Record 28 of Set 3 | asfi
# Processing Record 29 of Set 3 | labuhan
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | bilma
# Processing Record 32 of Set 3 | la rioja
# Processing Record 33 of Set 3 | mahibadhoo
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | gao
# Processing Record 37 of Set 3 | puerto baquerizo moreno
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | bambanglipuro
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | olafsvik
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | angoche
# Processing Record 46 of Set 3 | puerto maldonado
# Processing Record 47 of Set 3 | mayumba
# Processing Record 48 of Set 3 | nautla
# Processing Record 49 of Set 3 | aranos
# Processing Record 50 of Set 3 | bukama
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | princeton
# Processing Record 3 of Set 4 | mineros
# Processing Record 4 of Set 4 | robinson
# Processing Record 5 of Set 4 | ornskoldsvik
# Processing Record 6 of Set 4 | progreso
# Processing Record 7 of Set 4 | pau brasil
# Processing Record 8 of Set 4 | corinto
# Processing Record 9 of Set 4 | yumen
# Processing Record 10 of Set 4 | never
# Processing Record 11 of Set 4 | lompoc
# Processing Record 12 of Set 4 | alice springs
# Processing Record 13 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | nouadhibou
# Processing Record 17 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 4 | grand-lahou
# Processing Record 19 of Set 4 | atuona
# Processing Record 20 of Set 4 | kasongo-lunda
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | mamakan
# Processing Record 23 of Set 4 | fonte boa
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | xichang
# Processing Record 26 of Set 4 | stornoway
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | shakawe
# Processing Record 29 of Set 4 | korla
# Processing Record 30 of Set 4 | san andres
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 4 | clyde river
# Processing Record 34 of Set 4 | murray bridge
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | naze
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | mareeba
# Processing Record 40 of Set 4 | kutum
# Processing Record 41 of Set 4 | natal
# Processing Record 42 of Set 4 | solnechnyy
# Processing Record 43 of Set 4 | santa isabel
# Processing Record 44 of Set 4 | muros
# Processing Record 45 of Set 4 | leningradskiy
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | barrhead
# Processing Record 48 of Set 4 | manta
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | stromness
# Processing Record 1 of Set 5 | narathiwat
# Processing Record 2 of Set 5 | cuiluan
# Processing Record 3 of Set 5 | bang saphan
# Processing Record 4 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | alugan
# Processing Record 7 of Set 5 | bolonchen
# City not found. Skipping...
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | povenets
# Processing Record 10 of Set 5 | kitimat
# Processing Record 11 of Set 5 | esperance
# Processing Record 12 of Set 5 | capreol
# Processing Record 13 of Set 5 | rivadavia
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | sainte-suzanne
# Processing Record 17 of Set 5 | mosquera
# Processing Record 18 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 5 | were ilu
# Processing Record 20 of Set 5 | karasjok
# Processing Record 21 of Set 5 | ankang
# Processing Record 22 of Set 5 | holme
# Processing Record 23 of Set 5 | plettenberg bay
# Processing Record 24 of Set 5 | kawalu
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | segou
# Processing Record 27 of Set 5 | quang ngai
# Processing Record 28 of Set 5 | srednekolymsk
# Processing Record 29 of Set 5 | rio grande
# Processing Record 30 of Set 5 | vaitape
# Processing Record 31 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 5 | bajil
# Processing Record 33 of Set 5 | berezovyy
# Processing Record 34 of Set 5 | shingu
# Processing Record 35 of Set 5 | sand
# Processing Record 36 of Set 5 | upata
# Processing Record 37 of Set 5 | sterling
# Processing Record 38 of Set 5 | sao borja
# Processing Record 39 of Set 5 | geraldton
# Processing Record 40 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 5 | san joaquin
# Processing Record 42 of Set 5 | ketchikan
# Processing Record 43 of Set 5 | chulym
# Processing Record 44 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | waingapu
# Processing Record 47 of Set 5 | petrolandia
# City not found. Skipping...
# Processing Record 48 of Set 5 | santa rosa
# Processing Record 49 of Set 5 | saint-philippe
# Processing Record 50 of Set 5 | mecca
# Processing Record 1 of Set 6 | bom jesus
# Processing Record 2 of Set 6 | balykshi
# Processing Record 3 of Set 6 | pardina
# Processing Record 4 of Set 6 | benguela
# Processing Record 5 of Set 6 | ca mau
# Processing Record 6 of Set 6 | port-cartier
# Processing Record 7 of Set 6 | rudnogorsk
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | bullhead city
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | agadir
# Processing Record 13 of Set 6 | beira
# Processing Record 14 of Set 6 | sandakan
# Processing Record 15 of Set 6 | acari
# Processing Record 16 of Set 6 | kudahuvadhoo
# Processing Record 17 of Set 6 | nizhniy kuranakh
# Processing Record 18 of Set 6 | nelson bay
# Processing Record 19 of Set 6 | krasnoselkup
# Processing Record 20 of Set 6 | nipawin
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | rocha
# Processing Record 23 of Set 6 | tuy hoa
# Processing Record 24 of Set 6 | maniitsoq
# Processing Record 25 of Set 6 | touros
# Processing Record 26 of Set 6 | mangalam
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | batagay
# Processing Record 29 of Set 6 | ancud
# Processing Record 30 of Set 6 | mehamn
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | husavik
# Processing Record 33 of Set 6 | denpasar
# Processing Record 34 of Set 6 | mumford
# Processing Record 35 of Set 6 | chifeng
# Processing Record 36 of Set 6 | buala
# Processing Record 37 of Set 6 | vangaindrano
# Processing Record 38 of Set 6 | gualaquiza
# Processing Record 39 of Set 6 | paita
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | mangrol
# Processing Record 42 of Set 6 | kamariotissa
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | piryion
# City not found. Skipping...
# Processing Record 45 of Set 6 | flin flon
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | terra nova
# Processing Record 48 of Set 6 | gualaca
# Processing Record 49 of Set 6 | jerantut
# Processing Record 50 of Set 6 | yatou
# Processing Record 1 of Set 7 | terney
# Processing Record 2 of Set 7 | konongo
# Processing Record 3 of Set 7 | coihaique
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | college
# Processing Record 6 of Set 7 | marysville
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | gigmoto
# Processing Record 9 of Set 7 | parkersburg
# Processing Record 10 of Set 7 | sabzevar
# Processing Record 11 of Set 7 | bermeo
# Processing Record 12 of Set 7 | mocuba
# Processing Record 13 of Set 7 | ulaangom
# Processing Record 14 of Set 7 | kavieng
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | namibe
# Processing Record 17 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 7 | abha
# Processing Record 19 of Set 7 | linxia
# Processing Record 20 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | volksrust
# Processing Record 23 of Set 7 | saint-leu
# Processing Record 24 of Set 7 | charlestown
# Processing Record 25 of Set 7 | usinsk
# Processing Record 26 of Set 7 | calama
# Processing Record 27 of Set 7 | la palma
# Processing Record 28 of Set 7 | beneditinos
# Processing Record 29 of Set 7 | spisska nova ves
# Processing Record 30 of Set 7 | wamba
# Processing Record 31 of Set 7 | lasa
# Processing Record 32 of Set 7 | minador do negrao
# Processing Record 33 of Set 7 | chicama
# Processing Record 34 of Set 7 | turukhansk
# Processing Record 35 of Set 7 | udachnyy
# Processing Record 36 of Set 7 | arlit
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | luderitz
# Processing Record 39 of Set 7 | ibipeba
# Processing Record 40 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 7 | san policarpo
# Processing Record 42 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 7 | yerbogachen
# Processing Record 44 of Set 7 | tahta
# Processing Record 45 of Set 7 | athni
# Processing Record 46 of Set 7 | kurilsk
# Processing Record 47 of Set 7 | villa del rosario
# Processing Record 48 of Set 7 | ambilobe
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | marquette
# Processing Record 1 of Set 8 | te anau
# Processing Record 2 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 8 | sosnovoborsk
# Processing Record 5 of Set 8 | zyryanka
# Processing Record 6 of Set 8 | verkhnevilyuysk
# Processing Record 7 of Set 8 | bandarbeyla
# Processing Record 8 of Set 8 | caorle
# Processing Record 9 of Set 8 | simao
# Processing Record 10 of Set 8 | numaligarh
# Processing Record 11 of Set 8 | hofn
# Processing Record 12 of Set 8 | dicabisagan
# Processing Record 13 of Set 8 | tommot
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | moussoro
# Processing Record 17 of Set 8 | moerai
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | longyearbyen
# Processing Record 20 of Set 8 | dera bugti
# Processing Record 21 of Set 8 | huarmey
# Processing Record 22 of Set 8 | quartucciu
# Processing Record 23 of Set 8 | pitsunda
# Processing Record 24 of Set 8 | san jose
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | gayny
# Processing Record 27 of Set 8 | christchurch
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | strezhevoy
# Processing Record 30 of Set 8 | los arcos
# Processing Record 31 of Set 8 | ajaccio
# Processing Record 32 of Set 8 | colombes
# Processing Record 33 of Set 8 | hovd
# Processing Record 34 of Set 8 | mabaruma
# Processing Record 35 of Set 8 | kununurra
# Processing Record 36 of Set 8 | bairiki
# Processing Record 37 of Set 8 | port macquarie
# Processing Record 38 of Set 8 | moron
# Processing Record 39 of Set 8 | coquimbo
# Processing Record 40 of Set 8 | esna
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | rab
# City not found. Skipping...
# Processing Record 43 of Set 8 | kendal
# Processing Record 44 of Set 8 | okhotsk
# Processing Record 45 of Set 8 | ayan
# Processing Record 46 of Set 8 | newton
# Processing Record 47 of Set 8 | xique-xique
# Processing Record 48 of Set 8 | kismayo
# Processing Record 49 of Set 8 | balkhash
# Processing Record 50 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 9 | outram
# Processing Record 2 of Set 9 | cascais
# Processing Record 3 of Set 9 | rognan
# Processing Record 4 of Set 9 | pineville
# Processing Record 5 of Set 9 | san vicente
# Processing Record 6 of Set 9 | camabatela
# Processing Record 7 of Set 9 | yokadouma
# Processing Record 8 of Set 9 | yeppoon
# Processing Record 9 of Set 9 | boffa
# Processing Record 10 of Set 9 | salalah
# Processing Record 11 of Set 9 | mingrelskaya
# Processing Record 12 of Set 9 | wewak
# Processing Record 13 of Set 9 | potchefstroom
# Processing Record 14 of Set 9 | outjo
# Processing Record 15 of Set 9 | keflavik
# Processing Record 16 of Set 9 | monterey
# Processing Record 17 of Set 9 | port lincoln
# Processing Record 18 of Set 9 | ponta do sol
# Processing Record 19 of Set 9 | gravdal
# Processing Record 20 of Set 9 | dakar
# Processing Record 21 of Set 9 | mnogovershinnyy
# Processing Record 22 of Set 9 | soe
# Processing Record 23 of Set 9 | ercis
# Processing Record 24 of Set 9 | praia da vitoria
# Processing Record 25 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 9 | langevag
# Processing Record 27 of Set 9 | minuri
# Processing Record 28 of Set 9 | portland
# Processing Record 29 of Set 9 | evensk
# Processing Record 30 of Set 9 | porto novo
# Processing Record 31 of Set 9 | grand-santi
# Processing Record 32 of Set 9 | havoysund
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | camana
# Processing Record 35 of Set 9 | buin
# Processing Record 36 of Set 9 | mount gambier
# Processing Record 37 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | shu
# Processing Record 40 of Set 9 | takoradi
# Processing Record 41 of Set 9 | dondukovskaya
# Processing Record 42 of Set 9 | fremont
# Processing Record 43 of Set 9 | talnakh
# Processing Record 44 of Set 9 | manokwari
# Processing Record 45 of Set 9 | verkh-usugli
# Processing Record 46 of Set 9 | severo-yeniseyskiy
# Processing Record 47 of Set 9 | kyren
# Processing Record 48 of Set 9 | seidu
# Processing Record 49 of Set 9 | koumac
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | hadejia
# Processing Record 2 of Set 10 | astaneh-ye ashrafiyeh
# Processing Record 3 of Set 10 | ahipara
# Processing Record 4 of Set 10 | tukrah
# Processing Record 5 of Set 10 | binzhou
# Processing Record 6 of Set 10 | isangel
# Processing Record 7 of Set 10 | san patricio
# Processing Record 8 of Set 10 | bilibino
# Processing Record 9 of Set 10 | qaqortoq
# Processing Record 10 of Set 10 | estacion coahuila
# Processing Record 11 of Set 10 | matara
# Processing Record 12 of Set 10 | placer
# Processing Record 13 of Set 10 | cabinda
# Processing Record 14 of Set 10 | vila velha
# Processing Record 15 of Set 10 | minab
# Processing Record 16 of Set 10 | alofi
# Processing Record 17 of Set 10 | patan
# Processing Record 18 of Set 10 | leshukonskoye
# Processing Record 19 of Set 10 | felanitx
# Processing Record 20 of Set 10 | visby
# Processing Record 21 of Set 10 | cobija
# Processing Record 22 of Set 10 | san quintin
# Processing Record 23 of Set 10 | anadyr
# Processing Record 24 of Set 10 | patea
# Processing Record 25 of Set 10 | dunda
# Processing Record 26 of Set 10 | lodja
# Processing Record 27 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 10 | nyurba
# Processing Record 29 of Set 10 | concordia
# Processing Record 30 of Set 10 | monster
# Processing Record 31 of Set 10 | salisbury
# Processing Record 32 of Set 10 | sao miguel do araguaia
# Processing Record 33 of Set 10 | ambulu
# Processing Record 34 of Set 10 | sorong
# Processing Record 35 of Set 10 | sibu
# Processing Record 36 of Set 10 | nabire
# Processing Record 37 of Set 10 | qostanay
# Processing Record 38 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 10 | marrakesh
# Processing Record 40 of Set 10 | burnie
# Processing Record 41 of Set 10 | mantua
# Processing Record 42 of Set 10 | voi
# Processing Record 43 of Set 10 | fayaoue
# Processing Record 44 of Set 10 | hammerfest
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | pundaguitan
# Processing Record 47 of Set 10 | yungkang
# City not found. Skipping...
# Processing Record 48 of Set 10 | nova vicosa
# Processing Record 49 of Set 10 | akhmim
# Processing Record 50 of Set 10 | vetovo
# Processing Record 1 of Set 11 | barstow
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | erdenet
# Processing Record 5 of Set 11 | el dovio
# Processing Record 6 of Set 11 | lipari
# Processing Record 7 of Set 11 | vostok
# Processing Record 8 of Set 11 | hoa binh
# Processing Record 9 of Set 11 | shelburne
# Processing Record 10 of Set 11 | saint-joseph
# Processing Record 11 of Set 11 | kroya
# Processing Record 12 of Set 11 | pedra branca
# Processing Record 13 of Set 11 | crossville
# Processing Record 14 of Set 11 | urusha
# Processing Record 15 of Set 11 | dawlatabad
# Processing Record 16 of Set 11 | mountain home
# Processing Record 17 of Set 11 | moose factory
# Processing Record 18 of Set 11 | beidao
# Processing Record 19 of Set 11 | zorgo
# Processing Record 20 of Set 11 | san juan
# Processing Record 21 of Set 11 | cortez
# Processing Record 22 of Set 11 | salekhard
# Processing Record 23 of Set 11 | umm lajj
# Processing Record 24 of Set 11 | southbridge
# Processing Record 25 of Set 11 | finschhafen
# Processing Record 26 of Set 11 | meulaboh
# Processing Record 27 of Set 11 | tomatlan
# Processing Record 28 of Set 11 | comodoro rivadavia
# Processing Record 29 of Set 11 | bethel
# Processing Record 30 of Set 11 | necochea
# Processing Record 31 of Set 11 | sangar
# Processing Record 32 of Set 11 | ipixuna
# Processing Record 33 of Set 11 | sudzha
# Processing Record 34 of Set 11 | monroe
# Processing Record 35 of Set 11 | hailar
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | nuuk
# Processing Record 38 of Set 11 | pontianak
# Processing Record 39 of Set 11 | galveston
# Processing Record 40 of Set 11 | lethem
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 11 | baculin
# Processing Record 44 of Set 11 | mongo
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | babu
# Processing Record 47 of Set 11 | manoel urbano
# Processing Record 48 of Set 11 | sinnamary
# Processing Record 49 of Set 11 | egvekinot
# Processing Record 50 of Set 11 | mvuma
# Processing Record 1 of Set 12 | aripuana
# Processing Record 2 of Set 12 | plouzane
# Processing Record 3 of Set 12 | akdepe
# Processing Record 4 of Set 12 | strelitsa
# Processing Record 5 of Set 12 | eyl
# Processing Record 6 of Set 12 | los llanos de aridane
# Processing Record 7 of Set 12 | pampa
# Processing Record 8 of Set 12 | cabo san lucas
# Processing Record 9 of Set 12 | sidi ali
# Processing Record 10 of Set 12 | mandera
# Processing Record 11 of Set 12 | colares
# Processing Record 12 of Set 12 | jishou
# Processing Record 13 of Set 12 | sungurlu
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | batagay-alyta
# Processing Record 16 of Set 12 | tuatapere
# Processing Record 17 of Set 12 | dukat
# Processing Record 18 of Set 12 | golkoy
# Processing Record 19 of Set 12 | nsukka
# Processing Record 20 of Set 12 | kalmunai
# Processing Record 21 of Set 12 | manado
# Processing Record 22 of Set 12 | katangli
# Processing Record 23 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 12 | voskresenskoye
# Processing Record 25 of Set 12 | wanderlandia
# City not found. Skipping...
# Processing Record 26 of Set 12 | biak
# Processing Record 27 of Set 12 | orotukan
# Processing Record 28 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 12 | la asuncion
# Processing Record 30 of Set 12 | north bend
# Processing Record 31 of Set 12 | neiafu
# Processing Record 32 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 12 | qasigiannguit
# Processing Record 34 of Set 12 | burica
# City not found. Skipping...
# Processing Record 35 of Set 12 | halifax
# Processing Record 36 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 12 | shiraz
# Processing Record 38 of Set 12 | at-bashi
# Processing Record 39 of Set 12 | puerto rondon
# Processing Record 40 of Set 12 | castrillon
# Processing Record 41 of Set 12 | manitouwadge
# Processing Record 42 of Set 12 | golyshmanovo
# Processing Record 43 of Set 12 | basco
# Processing Record 44 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 12 | prince rupert
# Processing Record 46 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 12 | dordrecht
# Processing Record 48 of Set 12 | kijang
# Processing Record 49 of Set 12 | honiara
# Processing Record 50 of Set 12 | lisakovsk
# Processing Record 1 of Set 13 | maarianhamina
# Processing Record 2 of Set 13 | makakilo city
# Processing Record 3 of Set 13 | tungor
# Processing Record 4 of Set 13 | mindelo
# Processing Record 5 of Set 13 | claremore
# Processing Record 6 of Set 13 | shizilu
# Processing Record 7 of Set 13 | the valley
# Processing Record 8 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 9 of Set 13 | barcelos
# Processing Record 10 of Set 13 | puerto madero
# Processing Record 11 of Set 13 | brae
# Processing Record 12 of Set 13 | waddan
# Processing Record 13 of Set 13 | yekimovichi
# Processing Record 14 of Set 13 | cedar city
# Processing Record 15 of Set 13 | port blair
# Processing Record 16 of Set 13 | beyneu
# Processing Record 17 of Set 13 | bima
# Processing Record 18 of Set 13 | poronaysk
# Processing Record 19 of Set 13 | mityana
# Processing Record 20 of Set 13 | cozumel
# Processing Record 21 of Set 13 | menongue
# Processing Record 22 of Set 13 | radhanpur
# Processing Record 23 of Set 13 | goderich
# Processing Record 24 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 13 | camacupa
# Processing Record 26 of Set 13 | peniche
# Processing Record 27 of Set 13 | roebourne
# Processing Record 28 of Set 13 | wunsiedel
# Processing Record 29 of Set 13 | yagodnoye
# Processing Record 30 of Set 13 | chokwe
# Processing Record 31 of Set 13 | pinega
# Processing Record 32 of Set 13 | inuvik
# Processing Record 33 of Set 13 | meadow lake
# Processing Record 34 of Set 13 | northam
# Processing Record 35 of Set 13 | kolokani
# Processing Record 36 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 13 | san cristobal
# Processing Record 38 of Set 13 | harper
# Processing Record 39 of Set 13 | belmonte
# Processing Record 40 of Set 13 | vestmanna
# Processing Record 41 of Set 13 | caibarien
# Processing Record 42 of Set 13 | sakmara
# Processing Record 43 of Set 13 | chumikan
# Processing Record 44 of Set 13 | moissala
# Processing Record 45 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 46 of Set 13 | pecos
# Processing Record 47 of Set 13 | maracaibo
# Processing Record 48 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 13 | labuan
# Processing Record 50 of Set 13 | komsomolskiy
# Processing Record 1 of Set 14 | lamont
# Processing Record 2 of Set 14 | dalhousie
# Processing Record 3 of Set 14 | jaguarao
# Processing Record 4 of Set 14 | miki
# Processing Record 5 of Set 14 | ustye
# Processing Record 6 of Set 14 | kholodnyy
# Processing Record 7 of Set 14 | noumea
# Processing Record 8 of Set 14 | xuddur
# Processing Record 9 of Set 14 | saint anthony
# Processing Record 10 of Set 14 | veraval
# Processing Record 11 of Set 14 | goteborg
# City not found. Skipping...
# Processing Record 12 of Set 14 | languyan
# Processing Record 13 of Set 14 | sarab
# Processing Record 14 of Set 14 | inhambane
# Processing Record 15 of Set 14 | korgen
# Processing Record 16 of Set 14 | killam
# Processing Record 17 of Set 14 | bretzfeld
# Processing Record 18 of Set 14 | cabedelo
# Processing Record 19 of Set 14 | quatre cocos
# Processing Record 20 of Set 14 | iralaya
# Processing Record 21 of Set 14 | lishu
# Processing Record 22 of Set 14 | skibbereen
# Processing Record 23 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 14 | shimoda
# Processing Record 25 of Set 14 | fulton
# Processing Record 26 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 14 | concepcion del uruguay
# Processing Record 28 of Set 14 | jaque
# Processing Record 29 of Set 14 | chara
# Processing Record 30 of Set 14 | sola
# Processing Record 31 of Set 14 | sorland
# Processing Record 32 of Set 14 | tecoanapa
# Processing Record 33 of Set 14 | caraballeda
# Processing Record 34 of Set 14 | pointe-noire
# Processing Record 35 of Set 14 | whitehorse
# Processing Record 36 of Set 14 | champerico
# Processing Record 37 of Set 14 | dhidhdhoo
# Processing Record 38 of Set 14 | yaritagua
# Processing Record 39 of Set 14 | sanandaj
# Processing Record 40 of Set 14 | tres arroyos
# Processing Record 41 of Set 14 | poros
# Processing Record 42 of Set 14 | tahoua
# Processing Record 43 of Set 14 | ambunti
# Processing Record 44 of Set 14 | acoyapa
# Processing Record 45 of Set 14 | lagoa
# Processing Record 46 of Set 14 | batemans bay
# Processing Record 47 of Set 14 | bathsheba
# Processing Record 48 of Set 14 | saint stephen
# Processing Record 49 of Set 14 | daru
# Processing Record 50 of Set 14 | lichtenburg
# Processing Record 1 of Set 15 | hellin
# Processing Record 2 of Set 15 | marawi
# Processing Record 3 of Set 15 | rio gallegos
# Processing Record 4 of Set 15 | madang
# Processing Record 5 of Set 15 | hamilton
# Processing Record 6 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 15 | chimbote
# Processing Record 8 of Set 15 | siquirres
# Processing Record 9 of Set 15 | tigzirt
# Processing Record 10 of Set 15 | grindavik
# Processing Record 11 of Set 15 | puerto rico
# Processing Record 12 of Set 15 | khonsa
# Processing Record 13 of Set 15 | kashi
# Processing Record 14 of Set 15 | belyy yar
# Processing Record 15 of Set 15 | price
# Processing Record 16 of Set 15 | hualmay
# Processing Record 17 of Set 15 | sohag
# Processing Record 18 of Set 15 | uberaba
# Processing Record 19 of Set 15 | katsuura
# Processing Record 20 of Set 15 | hobyo
# Processing Record 21 of Set 15 | kuching
# Processing Record 22 of Set 15 | simav
# Processing Record 23 of Set 15 | mandalgovi
# Processing Record 24 of Set 15 | praia
# Processing Record 25 of Set 15 | valparaiso
# Processing Record 26 of Set 15 | kayasula
# Processing Record 27 of Set 15 | namatanai
# Processing Record 28 of Set 15 | virginia beach
# Processing Record 29 of Set 15 | manaure
# Processing Record 30 of Set 15 | mackenzie
# Processing Record 31 of Set 15 | surgut
# Processing Record 32 of Set 15 | hvittingfoss
# Processing Record 33 of Set 15 | lazaro cardenas
# Processing Record 34 of Set 15 | schattdorf
# Processing Record 35 of Set 15 | dunedin
# Processing Record 36 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 15 | abu dhabi
# Processing Record 38 of Set 15 | sur
# Processing Record 39 of Set 15 | pangai
# Processing Record 40 of Set 15 | ramsar
# Processing Record 41 of Set 15 | khasan
# Processing Record 42 of Set 15 | dvinskoy
# Processing Record 43 of Set 15 | lubango
# Processing Record 44 of Set 15 | banes
# Processing Record 45 of Set 15 | aksarka
# Processing Record 46 of Set 15 | vazante
# Processing Record 47 of Set 15 | anage
# Processing Record 48 of Set 15 | ola
# Processing Record 49 of Set 15 | puerto carreno
# Processing Record 50 of Set 15 | margate
# Processing Record 1 of Set 16 | himora
# City not found. Skipping...
# Processing Record 2 of Set 16 | wajima
# Processing Record 3 of Set 16 | kaniama
# Processing Record 4 of Set 16 | verkhoyansk
# Processing Record 5 of Set 16 | launceston
# Processing Record 6 of Set 16 | ulladulla
# Processing Record 7 of Set 16 | mitsamiouli
# Processing Record 8 of Set 16 | la reforma
# Processing Record 9 of Set 16 | beeville
# Processing Record 10 of Set 16 | agirish
# Processing Record 11 of Set 16 | mtambile
# Processing Record 12 of Set 16 | owando
# Processing Record 13 of Set 16 | forecariah
# Processing Record 14 of Set 16 | raver
# Processing Record 15 of Set 16 | vanimo
# Processing Record 16 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 16 | yulin
# Processing Record 18 of Set 16 | kindu
# Processing Record 19 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 16 | skjervoy
# Processing Record 21 of Set 16 | coahuayana
# Processing Record 22 of Set 16 | surab
# Processing Record 23 of Set 16 | zavoronezhskoye
# Processing Record 24 of Set 16 | esmeraldas
# Processing Record 25 of Set 16 | muhos
# Processing Record 26 of Set 16 | manyana
# Processing Record 27 of Set 16 | mfou
# Processing Record 28 of Set 16 | westport
# Processing Record 29 of Set 16 | lovozero
# Processing Record 30 of Set 16 | goure
# Processing Record 31 of Set 16 | gabu
# Processing Record 32 of Set 16 | odesskoye
# Processing Record 33 of Set 16 | darhan
# Processing Record 34 of Set 16 | naryan-mar
# Processing Record 35 of Set 16 | coruripe
# Processing Record 36 of Set 16 | tanete
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 729

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Malabo   3.7500    8.7833     85.86        74          20
# 1      Cape Town -33.9258   18.4232     72.10        42          20
# 2   Punta Arenas -53.1500  -70.9167     50.02        61          40
# 3      Saskylakh  71.9167  114.0833    -14.24        94         100
# 4       Shitkino  56.3703   98.3543      7.77        92         100
# 5  Ponta Delgada  37.7333  -25.6667     61.52       100          75
# 6         Rawson -43.3002  -65.1023     74.73        34          24
# 7       Thompson  55.7435  -97.8558      1.56        78         100
# 8        Ushuaia -54.8000  -68.3000     40.66        87         100
# 9          Pevek  69.7008  170.3133     -8.90        97         100
#
#    Wind Speed Country Current Description
# 0        8.05      GQ          few clouds
# 1       26.46      ZA          few clouds
# 2       43.73      CL    scattered clouds
# 3        9.78      RU     overcast clouds
# 4        9.44      RU     overcast clouds
# 5       19.57      PT       broken clouds
# 6       19.57      AR          few clouds
# 7        6.91      CA          light snow
# 8       19.57      AR       moderate rain
# 9       11.05      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Malabo      GQ   3.7500    8.7833     85.86        74          20
# 1       Cape Town      ZA -33.9258   18.4232     72.10        42          20
# 2    Punta Arenas      CL -53.1500  -70.9167     50.02        61          40
# 3       Saskylakh      RU  71.9167  114.0833    -14.24        94         100
# 4        Shitkino      RU  56.3703   98.3543      7.77        92         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 724     Odesskoye      RU  54.2111   72.9651    -11.27       100          81
# 725        Darhan      MN  49.4867  105.9228     -7.49        95          83
# 726    Naryan-Mar      RU  67.6713   53.0870      4.62        92         100
# 727      Coruripe      BR -10.1256  -36.1756     84.81        55           6
# 728        Tanete      ID  -3.9443  119.7848     75.92        92         100
#
#      Wind Speed Current Description
# 0          8.05          few clouds
# 1         26.46          few clouds
# 2         43.73    scattered clouds
# 3          9.78     overcast clouds
# 4          9.44     overcast clouds
# ..          ...                 ...
# 724        3.11       broken clouds
# 725        3.60       broken clouds
# 726       12.73     overcast clouds
# 727       11.12           clear sky
# 728        5.03          light rain
#
# [729 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
print(city_data_df.dtypes)
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
